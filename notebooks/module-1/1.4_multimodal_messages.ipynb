# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.5-flash-lite", model_provider="google_genai")

# from langchain_google_genai import ChatGoogleGenerativeAI

# model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")


agent = create_agent(
    model=model,
    system_prompt="你是一名科幻作家，应用户要求打造一座都城",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "月球的首都在哪里"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# 好的，我的科幻作家朋友！关于“月球的首都在哪里”这个问题，这可不是一个简单的问题，它涉及到一个宏伟的构想，一个在月球上建立文明的梦想。我的答案会结合科学的可能性、人类的想象以及我对未来文明的憧憬。
#
# **答案：月球的首都，不是一个固定的地理位置，而是一个动态的、不断演化的“中心”。它存在于以下几个层面，并最终指向一个最有可能的“核心”：**
#
# **1. 概念与象征的首都：月球轨道空间站“静谧之环” (Serene Ring)**
#
# 在早期，当人类的足迹刚刚踏上月球，并且为了安全和高效的资源利用，我们可能会选择先建立一个强大的轨道设施。这个设施，名为“静谧之环”，将是月球殖民的指挥中心、科研枢纽、也是对外交流的门户。
#
# *   **外观构想：** 一个巨大的、由多个模块组合而成的环形空间站，围绕月球旋转，能够提供稳定的重力环境，并且拥有无与伦比的月球全景。它的大部分区域会对外展示，成为月球人类文明最醒目的象征。
# *   **功能：** 集中管理月球上的所有殖民地，进行太空资源开采的统一调度，是所有月球居民的“安全港”和“信息中心”。所有重大的政治、经济、科研决策都将在这里做出。
# *   **为何是首都：** 在早期，它拥有最高的权力和影响力，代表着月球文明的集体意志。它不是一个“地点”，而是一个“存在”。
#
# **2. 功能与运营的首都：月球南极永昼区的“极光城” (Aurora City)**
#
# 随着殖民地的发展，人口的增加，以及对月球表面资源和环境的深入开发，实体城市的出现是必然的。而最理想的建城地点，我将其命名为“极光城”，位于月球南极的永昼区。
#
# *   **地理位置的优势：**
#     *   **永昼：** 靠近南极的某些区域，拥有长达数月的永昼（或永夜），这意味着稳定的太阳能供应，这对于能源驱动的城市至关重要。
#     *   **水冰资源：** 这些区域也更有可能储存水冰，这是生命维持、工业生产和火箭燃料的关键。
#     *   **地质稳定性：** 相较于月球赤道地区，极地可能更具地质稳定性，也更容易进行地下挖掘和建设。
# *   **外观构想：** 极光城并非一座露天的城市。为了抵御月球真空、辐射和极端温差，它将是多层、地下为主、地表为辅的巨型复合体。
#     *   **地下穹顶：** 巨大的地下空间，内部模拟地球环境，有绿意盎然的植物，有人造天空。
#     *   **地表结构：** 覆盖着厚重的月岩和特制的防护材料，只在关键区域（如观景点、对接港）露出。
#     *   **命名“极光”：** 象征着新的黎明，也可能暗示着在永昼区，某些特殊的电离层现象（如果月球拥有的话）或者城市内部的能源流动，会产生类似极光的视觉效果。
# *   **为何是首都：** 这里将是月球人口最密集、经济最发达、文化最多元、政治权力最终落地的实体中心。所有重要的政府机构、大型企业、高等学府、文化娱乐设施都将汇聚于此。
#
# **3. 潜在的、更具哲学意味的首都：“寂静海”的“智核” (The Nexus of Tranquility)**
#
# 如果月球文明发展到更高的阶段，不再仅仅是为了生存和扩张，而是追求智慧和内省，那么首都的形态可能会更加抽象。
#
# *   **地点：** 月球正面，我们最熟悉的“静海”（Mare Tranquillitatis）附近。这个名字本身就带有宁静与深邃的意涵。
# *   **构想：“智核”** 这不是一个物理城市，而是一个由高度发达的人工智能、庞大的数据网络、以及可能存在的、与月球本身物质或能量交互的“意识节点”组成的集合体。它可能隐藏在月球的深处，或者以一种我们尚未理解的形态存在。
# *   **功能：** 它是月球文明的“大脑”，负责处理最复杂的宇宙信息，模拟未来，甚至与宇宙深处的未知智慧进行“交流”。普通居民可能很少能接触到它，但它的存在，决定了月球文明的走向。
# *   **为何是首都：** 在这个阶段，“首都”的定义不再是人口或权力中心，而是智慧和存在的核心。月球的“意志”可能就源于此。
#
# **最终的答案：**
#
# 就目前最符合逻辑的科幻发展路径而言，**月球的首都是“极光城” (Aurora City)**，一座位于月球南极永昼区，多层次、地下为主的巨型城市。它既是能源和资源利用的中心，也是人类在月球上建立的第一个真正意义上的、具有政治、经济、文化集散功能的家园。
#
# 然而，作为一名科幻作家，我更喜欢这种多层次的首都概念：
#
# *   **“静谧之环”** 是初期星辰大海征途中的**精神象征与指挥中心**。
# *   **“极光城”** 是人类在地表扎根后的**实体心脏与经济命脉**。
# *   而那些更深邃、更抽象的“首都”，则代表着月球文明走向**更高层次存在的可能性**。
#
# 所以，月球的首都在哪里？它始于轨道上的一个光点，落地于南极的永恒曙光，最终可能融入月球本身的寂静与智慧之中。这是一个不断被书写和定义的答案。
#
# 您觉得这个构想如何？您更倾向于哪一种首都形态？我们可以继续深入探讨！

# %% [markdown]
# ## 图像输入
#
# #### 多模态，就是大模型不仅可以识别文字，也可以去识别图像或者是声音，把图像，声音转换成信息的描述。
#
#
# <img src="./resources/moon.png" width="400" style="display:block; margin-left:0;">
#
# #### 例如，我们现在要让大模型帮我描述一张这张图片。

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x106c0ee00>, 'last_modified': datetime.datetime(2026, 5, 24, 13, 0, 12, 346000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "请描述这个都城"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# 欢迎来到“星辰之巅”，这座都城坐落在一个遥远、荒凉的星球上，但它本身却是一座生机勃勃的奇迹。
#
# **地理环境：**
# “星辰之巅”位于一个地质活动剧烈、拥有奇特地貌的星球。崎岖的山脉，如同巨龙的脊背，蜿蜒伸展，将都城环抱其中。星球表面覆盖着粗犷的岩石和尘埃，但在这荒芜之中，却孕育着奇特的景象。远处，巨大的蔚蓝色行星悬挂在深邃的星空中，散发出幽冷的光辉，照亮着这片陌生的土地。都城周围分布着一些散发着蓝光的湖泊，它们可能是某种奇特的能量源，或是外星生命的栖息地，为这座荒凉的星球增添了一抹神秘的色彩。
#
# **建筑风格：**
# 都城的建筑风格充满了未来感和科技感。高耸入云的尖塔式摩天大楼是城市的主体，它们由一种闪烁着金属光泽的材料建造而成，流线型的设计仿佛是为了抵御星球上的极端天气。这些建筑的外墙上镶嵌着发光的蓝色窗户和灯带，在暗夜中如同星辰般闪耀，勾勒出城市的轮廓。在城市的中央，有一个巨大的平台，将建筑群托起，仿佛一座漂浮在山谷中的岛屿。
#
# **城市功能与特色：**
# “星辰之巅”不仅仅是一个居住区，更是一个集科研、贸易、文化交流于一体的星际枢纽。
#
# *   **能源系统：** 城市周围的蓝色湖泊可能是其主要的能源来源，利用星球特有的地热或某种未知能量为城市提供动力。
# *   **交通系统：** 密布的建筑群之间可能通过磁悬浮列车或能量桥梁相连，实现高效便捷的交通。
# *   **防御系统：** 考虑到星球的荒凉和潜在的未知威胁，城市很可能拥有先进的防御系统，以保护居民的安全。
# *   **生态系统：** 尽管星球表面荒凉，但都城内部很可能建立了人工生态系统，提供清新的空气和宜人的环境，也可能种植着适应星球环境的奇特植物。
# *   **文化景观：** 在城市的中心或高处，可能设有观测台，供居民欣赏天体奇观，以及各种文化展览馆或艺术中心，展示来自不同星系的文明。
#
# **生活方式：**
# 居住在“星辰之巅”的居民，很可能是为了探索、科研或寻找新的资源而来到这里的。他们可能拥有先进的科技，能够适应并改造环境。生活方式可能高度智能化，科技渗透到生活的方方面面。同时，与外星文明的接触和交流，也可能丰富了他们的文化和视野。
#
# “星辰之巅”，这座在荒凉星球上崛起的人造奇迹，是人类（或其他智慧种族）探索宇宙、追求进步的象征。它既是科技的结晶，也是对未知世界的勇气和智慧的赞歌。

# %% [markdown]
# ## 音频输入

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 10  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 100/100 [00:10<00:00,  9.56it/s]
# Done.

# %%
agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "告诉我这段录音的内容"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# 这段录音的内容是：
#
# 录音的开头有人说“大家好，欢迎大家来到我的课堂，希望这个课堂对大家理解 Agent 能够有所帮助。谢谢。”
#
# 这段话是在一个课堂的开始，讲课人向听众致欢迎辞，并说明了这次课程的主题是关于“Agent”的，希望能够帮助大家理解。
